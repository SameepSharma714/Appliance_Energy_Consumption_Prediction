# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('KAG_energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='str')

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['days']=df['date'].dt.day

# %%
df['hour']=df['date'].dt.hour

# %%
df['dow']=df['date'].dt.day_of_week

# %%
df['is_weekend']=np.where(df['dow'].isin(['Sunday','Saturday']),1,0)

# %%
df.drop('dow',axis=1,inplace=True)

# %%
df['is_weekend']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19730    0
# 19731    0
# 19732    0
# 19733    0
# 19734    0
# Name: is_weekend, Length: 19735, dtype: int64

# %%
df.drop('date',axis=1,inplace=True)

# %%
##Outliers detection
print("highest allowed value of appliance",df['Appliances'].mean() + 3 * df['Appliances'].std())
print("lowest allowed value of appliance",df['Appliances'].mean() - 3 * df['Appliances'].std())
# Out:
# highest allowed value of appliance 405.269629808317
# lowest allowed value of appliance -209.8797134161204

# %%
(df['Appliances'] < 0).sum()
# Out:
# np.int64(0)

# %%
(df['Appliances'] > 1000).sum()
# Out:
# np.int64(2)

# %%
df.count()
# Out:
# Appliances     19735
# lights         19735
# T1             19735
# RH_1           19735
# T2             19735
# RH_2           19735
# T3             19735
# RH_3           19735
# T4             19735
# RH_4           19735
# T5             19735
# RH_5           19735
# T6             19735
# RH_6           19735
# T7             19735
# RH_7           19735
# T8             19735
# RH_8           19735
# T9             19735
# RH_9           19735
# T_out          19735
# Press_mm_hg    19735
# RH_out         19735
# Windspeed      19735
# Visibility     19735
# Tdewpoint      19735
# rv1            19735
# rv2            19735
# days           19735
# hour           19735
# is_weekend     19735
# dtype: int64

# %%
df[(df['Appliances']>405.26)|(df['Appliances']<-209.87)]
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 11            580      60  20.066667  46.396667  19.426667  44.400000
# 12            430      50  20.133333  48.000000  19.566667  44.400000
# 103           500       0  19.700000  45.590000  18.890000  44.230000
# 104           450       0  19.730000  47.793333  18.926667  44.230000
# 308           420      20  19.500000  41.326667  19.000000  40.500000
# ...           ...     ...        ...        ...        ...        ...
# 19684         580       0  23.633333  47.226667  24.814000  43.472000
# 19685         660       0  23.760000  47.693333  25.497143  42.595714
# 19695         620       0  24.356667  48.326667  26.777143  39.567143
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...  Press_mm_hg  \
# ...

# %%
##Outliers detection
print("highest allowed value of lights",df['lights'].mean() + 3 * df['lights'].std())
print("lowest allowed value of lights",df['lights'].mean() - 3 * df['lights'].std())
# Out:
# highest allowed value of lights 27.60983764229955
# lowest allowed value of lights -20.006087958995774

# %%
df[(df['lights']>27.60)|(df['lights']<-20.00)]
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19326          60      30  24.566667  40.200000  22.600000  40.626667
# 19387         110      30  23.390000  40.163333  21.000000  42.633333
# 19392         100      30  23.390000  39.826667  21.356667  41.566667
# 19397          90      30  23.390000  40.026667  24.133333  38.733333
# 19607          90      30  24.500000  44.700000  24.200000  41.500000
#
#             T3       RH_3         T4       RH_4  ...  Press_mm_hg     RH_out  \
# ...

# %%
df.columns
# Out:
# Index(['Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4',
#        'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9',
#        'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint', 'rv1', 'rv2', 'days', 'hour', 'is_weekend'],
#       dtype='str')

# %%
##Outliers detection
print("highest allowed value of T1",df['T1'].mean() + 3 * df['T1'].std())
print("lowest allowed value of T1",df['T1'].mean() - 3 * df['T1'].std())
# Out:
# highest allowed value of T1 26.504768321189292
# lowest allowed value of T1 16.86837445230554

# %%
df[(df['T1']>26.50)|(df['T1']<16.86)]
# Out:
#       Appliances  lights         T1       RH_1    T2       RH_2      T3  \
# 1717         130      20  16.823333  44.826667  16.2  44.626667  17.290
# 1722          60       0  16.856667  45.760000  16.1  45.590000  17.390
# 1723          40      10  16.856667  45.760000  16.1  45.590000  17.390
# 1724          50       0  16.790000  45.700000  16.1  45.560000  17.390
# 1725          70       0  16.790000  45.700000  16.1  45.500000  17.315
# 1726          80      10  16.790000  45.663333  16.1  45.500000  17.290
# 1727         120      10  16.790000  45.590000  16.1  45.500000  17.290
# 1728         120      10  16.790000  45.526667  16.1  45.466667  17.230
# 1729         420      10  16.790000  45.266667  16.1  45.326667  17.200
# 1730         410      20  16.790000  45.290000  16.1  45.363333  17.200
# 1731         240      10  16.790000  45.290000  16.1  45.290000  17.290
# 1732         220      10  16.790000  45.163333  16.1  45.290000  17.290
# ...

# %%
##Outliers detection
print("highest allowed value of RH_1",df['RH_1'].mean() + 3 * df['RH_1'].std())
print("lowest allowed value of RH_1",df['RH_1'].mean() - 3 * df['RH_1'].std())
# Out:
# highest allowed value of RH_1 52.197635771089246
# lowest allowed value of RH_1 28.321842788475784

# %%
df[(df['T1']>52.19)|(df['T1']<28.32)]
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...  Press_mm_hg  \
# ...
